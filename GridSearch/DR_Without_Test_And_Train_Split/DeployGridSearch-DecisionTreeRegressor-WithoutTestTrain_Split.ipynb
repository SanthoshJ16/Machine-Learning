# %%
#Deployment model for the Insurance charges prediction based on Inputs
import pickle

#load the final predicted Insurance charges model and store in variable load_model
grid=pickle.load(open("finalModel_GridSearchDecisionTreeRegressor_WithoutSplit.sav",'rb'))


# Ask user for input and store it on variable
age_input=float(input("Enter you Age: "))
bmi_input=float(input("Enter your BMI: "))
children_input=float(input("Enter Number of Children: "))
sex_input=int(input("Enter your Sex 0 or 1:"))
smoker_input=int(input("Do you Smoke ? 0 or 1:"))

# Run prediction using dynamic input and Grid Object
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_input]])
#,!change the paramter,play with it.

print("Predicted Insurance Charges is:", Future_Prediction)
# Out:
# Enter you Age:  32
# Enter your BMI:  43
# Enter Number of Children:  2
# Enter your Sex 0 or 1: 0
# Do you Smoke ? 0 or 1: 1
# Predicted Insurance Charges is: [14988.432]
